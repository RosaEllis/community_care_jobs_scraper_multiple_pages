# %% [markdown]
# # Web scraping the communitycare jobs site
#
# Using this tutorial https://www.dataquest.io/blog/web-scraping-beautifulsoup/
#
# This is to scrape MULTIPLE pages

# %%
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from time import time 
from random import randint
from warnings import warn
from IPython.core.display import clear_output

# %% [markdown]
# Import get from the requests libraries, then put the URL in a variable called url, then use the get method on url to grab the data, then print the first 500 characters to check it worked.
# response is a type of object called a Response object.

# %%
url = 'https://jobs.communitycare.co.uk/searchjobs/?Keywords=&radialtown=&LocationId=&RadialLocation=5'

response = get(url)

print(response.text[:500])
# Out:
# <!DOCTYPE html>
# 	<html data-placeholder-focus="false" lang="en-GB">
# 	<head>
# 		<!-- SiteScope -->
# 	    <meta charset="utf-8">
# 	    <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# 		<title>Search for a Social Care Job | Community Care Jobs</title>
#
#
# 				<link rel="stylesheet" href="//jobs.communitycare.co.uk/assets/dist/css/package.css;p=master,branding;v=7de15f9dc396b7ff563342f666351c2c" type="text/css">
#
#
#
#
# 		<!--[if lt IE 10]>
# 			<link rel="stylesheet" h

# %% [markdown]
# ## Import beautiful soup and parse
#
# Then use beautiful soup and the html parser to parse the content of the web page, and then check what type of object it is (it is a BeautifulSoup object).

# %%
from bs4 import BeautifulSoup

html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ## Work out what distinguishes each item (job) and use find_all() to grab them in one object
#
# In the browser, work out what tag or class distinguishes each element, by using 'view source' or developer tools.
#
# Then check the type of object (it should say bs4.elementbe a ResultSet)
#
# Then check the length of the object (the length should match the number of items on the page)

# %%
job_containers = html_soup.find_all('li', class_ = 'lister__item')
print(type(job_containers))
print(len(job_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 20

# %% [markdown]
# ## Work out EXACTLY which bits of data to grab
#
# E.g, job title, salary, region, description

# %% [markdown]
# ## Work out the code needed to drill down to the specific bits of data
#
# To do this put the first item of the ResultSet into a variable, so that I can just use one item to drill down on

# %%
first_job = job_containers[0]

# %% [markdown]
# Then use beautiful soup to drill down. There are different ways of doing it...
#
# -- If the bit of text you want is inside the first instance of a tag (e.g. the first h3 tag) you can use dot notation, e.g. first_job.h3, if it is further in you can chain them, e.g. first_job.h3.a (but this only works if all the tags are the first instances of them, i.e. if you want the text in the second h3 it won't work)
#
# -- If you want to find the first instance of a tag with a specific attribute you can use find(), e.g. first_job.find('div', class_ = 'lister_item'). Another way to do the same thing is putting the attribute name and value as a dictionary, e.g. first_job.find('div', attrs = {'class' = 'lister_item'})
#
# -- If you want to find the second, or third (or fourth etc) instance of a tag you can use find_all() and give it a number, e.g. first_job.find(h3)[1]
#
# -- If you want to grab the value of the attribute instead of the text, e.g. if you want a link, then cam put the name of the attribute in brackets, e.g. first_job.find('a')['href']

# %%
print(first_job)
# Out:
# <li class="lister__item cf lister__item--upsell lister__item--has-ribbon brand-highlight lister__item--premium-job lister__item--promoted-job lister__item--premium-job lister__item--promoted-job" id="item-1401610100">
# <div class="lister__details cf js-clickable">
# <h3 class="lister__header"><a class="js-clickable-area-link" href="
# 	/job/1401610100/supervising-social-worker/?LinkSource=PremiumListing
#
#
#
# "><span>Supervising Social Worker</span></a></h3>
# <img alt="Orange Grove Fostercare logo" class="lister__logo rec-logo float-right one-quarter portable-two-fifths palm-two-fifths" src="//jobs.communitycare.co.uk/getasset/0e60ec28-5862-499e-8313-cec96f78ad2c/"/>
# <ul class="lister__meta">
# <li class="lister__meta-item lister__meta-item--location">Stoke-on-Trent, Staffordshire</li>
# <li class="lister__meta-item lister__meta-item--salary">£30,000 - £37,000, £3,000 Car Allowance</li>
# <li class="lister__meta-item lister__meta-item--recruiter">Orange Grove Fostercare</li>
# </ul>
# <p class="lister__description js-clamp-2">We are looking for a committed social care professional with a sound knowledge of fostering legislation and practice issues.</p>
# </div>
# <div class="lister__footer cf">
# <p class="lister__view-details"><a class="button button--lister-view-details" href="
# 	/job/1401610100/supervising-social-worker/?LinkSource=PremiumListing
#
#
#
# ">View details</a></p>
# <ul class="job-actions float-right margin-top-5">
# <li class="job-actions__action job-actions__action--shortlist">
# <form action="/your-jobs/" class="js-shortlist-form" method="post">
# <input name="JobId" type="hidden" value="1401610100"/>
# <input name="ReturnUrl" type="hidden" value="~/searchjobs/?countrycode=GB#item-1401610100"/>
# <input name="Action" type="hidden" value="ShortlistJob"/>
# <button class="js-shortlist-trigger linkesque js-unshortlisted js-webui-popover" data-popover-content="#save-job-alert-text-1401610100" type="submit">
# <i class="icon-after" data-icon="☆" title="Add to shortlist"></i>
# <span class="js-text">Save</span>
# </button>
# <div class=" js-hide" id="save-job-alert-text-1401610100">You need to <a href="https://jobs.communitycare.co.uk/your-jobs/?JobId=1401610100&amp;Action=ShortlistJob&amp;ReturnUrl=~/your-jobs?ActiveSection=ShortList">sign in</a> or <a href="https://jobs.communitycare.co.uk/your-jobs/?JobId=1401610100&amp;Action=ShortlistJob&amp;ReturnUrl=~/your-jobs?ActiveSection=ShortList">create an account</a> to save</div>
# </form>
# </li>
# </ul>
# </div>
# </li>

# %%
job_title = first_job.span.text
print(job_title)
# Out:
# Supervising Social Worker

# %%
job_area = first_job.find('li', class_ = 'lister__meta-item--location').text
print(job_area)
# Out:
# Stoke-on-Trent, Staffordshire

# %%
job_salary = first_job.find('li', class_ = 'lister__meta-item--salary').text
print(job_salary)
# Out:
# £30,000 - £37,000, £3,000 Car Allowance

# %%
job_description = first_job.find('p', class_ = 'lister__description').text
print(job_description)
# Out:
# We are looking for a committed social care professional with a sound knowledge of fostering legislation and practice issues.

# %%
job_link = first_job.find('a')['href']
print(job_link)
# Out:
#
# 	/job/1401610100/supervising-social-worker/?LinkSource=PremiumListing

# %% [markdown]
# ## Putting it together
#
# Note the 's' at the end of some to make the variables different

# %%
job_title = []
job_area = []
job_salary = []
job_description = []
job_link = []

for jobs in job_containers: 
    
    # The job title
    job_titles = jobs.span.text
    job_title.append(job_titles)
    
    # The area 
    job_areas = jobs.find('li', class_ = 'lister__meta-item--location').text
    job_area.append(job_areas)
    
    # The salary
    job_salaries = jobs.find('li', class_ = 'lister__meta-item--salary').text
    job_salary.append(job_salaries)
    
    # The job description
    job_descriptions = jobs.find('p', class_ = 'lister__description').text 
    job_description.append(job_descriptions)
    
    # The link
    job_links = jobs.find('a')['href']
    job_link.append(job_links)

# %% [markdown]
# ## Use pandas to test it worked

# %%
test_df = pd.DataFrame({'job': job_title,
                       'area': job_area,
                        'salary': job_salary,
                        'description': job_description,
                        'link': job_link
                       })

test_df
# Out:
#                                                  area  \
# 0                       Stoke-on-Trent, Staffordshire
# 1                              Walsall, West Midlands
# 2                                  Haverhill, Suffolk
# 3                        Cirencester, Gloucestershire
# 4                                Banbury, Oxfordshire
# 5                                     Alvaston, Derby
# 6                                        Lincolnshire
# 7                           Lambeth, London (Greater)
# 8               Croydon (City/Town), London (Greater)
# 9   Hampshire Countywide (please note you must be ...
# 10                          England, Kent, Whitstable
# 11            England, Greater Manchester, Manchester
# 12                                 Greater Manchester
# 13                        England, South West England
# 14                                        Isle of Man
# 15                     England, West Yorkshire, Leeds
# 16                                Havant or Eastleigh
# 17                England, Northamptonshire, Brackley
# 18                 England, West Midlands, Birmingham
# 19                       Wolverhampton, West Midlands
#
#                                           description  \
# 0   We are looking for a committed social care pro...
# 1   Do you love going the extra mile for people to...
# 2   Do you love going the extra mile for people to...
# 3   Do you love going the extra mile for people to...
# 4   Do you love going the extra mile for people to...
# 5   Do you love going the extra mile for people to...
# 6   Families change. We change with them. That’s w...
# 7   We are looking for experienced Social Workers ...
# 8   Can you champion and drive service improvement...
# 9   What’s not to like about being a Hampshire Chi...
# 10  The successful candidate will manage a Childre...
# 11  A Newly Qualified Social Worker is required to...
# 12  A Greater Manchester local authority is lookin...
# 13  R&A Social Worker's Needed - Part Time Hours -...
# 14  We currently have a vacancy available for eith...
# 15  An "Outstanding" rated Independent Fostering A...
# 16  Hampshire County Council are seeking an innova...
# 17  Supported Living, Residential and Day Services...
# 18  An "Outstanding" rated Independent Fostering A...
# 19  3D Recruit are looking for an experienced Soci...
#
#                                                   job  \
# 0                           Supervising Social Worker
# 1                              Assistant Care Manager
# 2                     Care Assistant / Support Worker
# 3                     Care Assistant / Support Worker
# 4                     Care Assistant / Support Worker
# 5                     Care Assistant / Support Worker
# 6   Children's Social Worker - Level 2 - Lincolnshire
# 7   Experienced Social Workers - Children's Social...
# 8                    Team Managers Adolescent Service
# 9   Experienced Children's Qualified Social Worker...
# 10  Social Worker - Unaccompanied Asylum Seeking C...
# 11  Newly Qualified Social Worker - Duty and Asses...
# 12                            Qualified Social Worker
# 13       R&A Social Worker's Needed - Part Time Hours
# 14         Family Court Advisor - Children & Families
# 15  Supervising Social Worker - Independent Foster...
# 16  Social Worker - Adults Services (Learning Disa...
# 17                                    Support Worker
# 18  Supervising Social Worker - Independent Foster...
# 19  Qualified Social Worker – Looked after Childre...
#
#                                                  link  \
# 0    \r\n\t/job/1401610100/supervising-social-work...
# 1    \r\n\t/job/1401609580/assistant-care-manager/...
# 2    \r\n\t/job/1401609455/care-assistant-support-...
# 3    \r\n\t/job/1401609416/care-assistant-support-...
# 4    \r\n\t/job/1401609402/care-assistant-support-...
# 5    \r\n\t/job/1401609418/care-assistant-support-...
# 6    \r\n\t/job/1401599304/children-s-social-worke...
# 7    \r\n\t/job/1401609710/experienced-social-work...
# 8    \r\n\t/job/1401609342/team-managers-adolescen...
# 9    \r\n\t/job/1401608457/experienced-children-s-...
# 10   \r\n\t/job/1401610401/social-worker-unaccompa...
# 11   \r\n\t/job/1401610400/newly-qualified-social-...
# 12   \r\n\t/job/1401610282/qualified-social-worker...
# 13   \r\n\t/job/1401610399/r-and-a-social-worker-s...
# 14   \r\n\t/job/1401610398/family-court-advisor-ch...
# 15   \r\n\t/job/1401610397/supervising-social-work...
# 16   \r\n\t/job/1401610396/social-worker-adults-se...
# 17   \r\n\t/job/1401610395/support-worker-/\r\n\r\...
# 18   \r\n\t/job/1401610394/supervising-social-work...
# 19   \r\n\t/job/1401610392/qualified-social-worker...
#
#                                                salary
# 0             £30,000 - £37,000, £3,000 Car Allowance
# 1                                   £21,500 per annum
# 2                                      £8.96 per hour
# 3                                     £10.07 per hour
# 4                                     £10.05 per hour
# 5                                      £8.61 per hour
# 6                                   £30,153 - £33,437
# 7   PO3 Starting salary £37,650 pa rising to £40,6...
# 8                         Salary up £54,953 per annum
# 9   £32,109 - £36,139 per annum + market supplemen...
# 10                                 £28 - £32 per hour
# 11                              Up to £25.02 per hour
# 12  £30 per hour, possibly more depending on exper...
# 13                                 £28 - £31 per hour
# 14                           £30.00 - £35.00 per hour
# 15         £26000.00 - £32500.00 per annum + benefits
# 16                        £32,109 - £36,139 per annum
# 17                    £15000.00 - £16500.00 per annum
# 18         £26000.00 - £32500.00 per annum + benefits
# 19                                              28 ph

# %% [markdown]
# ## The full script
#
# This has to loop through the different URLs
#
# This is the URL: https://jobs.communitycare.co.uk/searchjobs/?countrycode=GB&Page=1

# %%
# Make a list of the bit that varies in the URL. Here it is just the page number, and there are 88 pages.
# The numbers have to be a string so they can be added in to the URL as a string, not a number 
pages = [str(i) for i in range(1,88)]

headers = {"Accept-Language": "en-US, en;q=0.5"}

# Create the lists
job_title = []
job_area = []
job_salary = []
job_description = []
job_link = [] 

# Prepare the monitoring of the loop
start_time = time()
requests = 0 

# For every page in the list of of pages
for page_number in pages: 
    
    # Make a get request 
    response = get('https://jobs.communitycare.co.uk/searchjobs/?countrycode=GB&Page=' + page_number)
    
    # Pause the loop
    sleep (randint(8,15))
    
    # Monitor the requests 
    requests += 1
    elapsed_time = time() - start_time 
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)
    
    # Throw a warning for non-200 status codes 
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(requests, response.status_code))
        
    # Break the loop if the number of requests is more than the number of pages I want to scrape 
    if requests > 88:
        warn('Number of requests is bigger than expected Rosa!')
        break 
    
    # Parse the content of the request with BeautifulSoup
    page_html = BeautifulSoup(response.text, 'html.parser')
    
    # Select the containers from a single page 
    job_containers = page_html.find_all('li', class_ = 'lister__item')
    
    # For every item on the page 
    for jobs in job_containers: 
        
        # The job title
        job_titles = jobs.span.text
        job_title.append(job_titles)
    
        # The area 
        job_areas = jobs.find('li', class_ = 'lister__meta-item--location').text
        job_area.append(job_areas)

        # The salary
        job_salaries = jobs.find('li', class_ = 'lister__meta-item--salary').text
        job_salary.append(job_salaries)

        # The job description
        job_descriptions = jobs.find('p', class_ = 'lister__description').text 
        job_description.append(job_descriptions)

        # The link
        job_links = jobs.find('a')['href']
        job_link.append(job_links)
# Out:
# Request:87; Frequency: 0.08049674202684205 requests/s

# %%
sc_jobs_df = pd.DataFrame({'job': job_title,
                       'area': job_area,
                        'salary': job_salary,
                        'description': job_description,
                        'link': job_link
                       })

sc_jobs_df
# Out:
#                                                    area  \
# 0                         Stoke-on-Trent, Staffordshire
# 1                                Walsall, West Midlands
# 2                                    Haverhill, Suffolk
# 3                          Cirencester, Gloucestershire
# 4                                  Banbury, Oxfordshire
# 5                                       Alvaston, Derby
# 6                                          Lincolnshire
# 7                             Lambeth, London (Greater)
# 8                 Croydon (City/Town), London (Greater)
# 9     Hampshire Countywide (please note you must be ...
# 10                                      England, London
# 11                                   South West England
# 12                                   South West England
# 13                                   England, Berkshire
# 14                  England, Greater Manchester, Bolton
# 15                           England, Surrey, Haslemere
# 16                   England, County Durham, Darlington
# 17                              England, London, Merton
# 18                          England, South West England
# 19                          England, South East England
# 20                                              England
# 21                      England, Merseyside, St. Helens
# 22                           England, Surrey, Haslemere
# 23                          England, South East England
# 24                          England, South East England
# 25                                   England, Berkshire
# 26                       England, Lancashire, Blackburn
# 27                  Stourport-on-Severn, Worcestershire
# 28                England, West Midlands, Wolverhampton
# 29           England, Warwickshire, Stratford-upon-Avon
# ...                                                 ...
# 1710  Havant, Hampshire (please note you must be abl...
# 1711  Farnborough, Hampshire (please note you must b...
# 1712  Gosport, Hampshire (please note you must be ab...
# 1713  Eastleigh, Hampshire (please note you must be ...
# 1714  Test Valley, Hampshire (please note you must b...
# 1715                                     Torquay, Devon
# 1716                                           Somerset
# 1717                        England, South West England
# 1718                                      England, Kent
# 1719  Basingstoke, Hampshire (please note you must b...
# 1720                                   London (Greater)
# 1721                                           Cornwall
# 1722                                      West Midlands
# 1723                                          Berkshire
# 1724                                          Berkshire
# 1725                                Preston, Lancashire
# 1726                                     Woking, Surrey
# 1727                      England, London, South London
# 1728                        England, South East England
# 1729                        England, South West England
# 1730                        England, South East England
# 1731                        England, South East England
# 1732                        England, South East England
# 1733                        England, North West England
# 1734                 England, West Midlands, Birmingham
# 1735                                          Berkshire
# 1739  MANAGEMENT EXPERIENCE - START IMMEDIATELY - NE...
#
#                                                     job  \
# 0                             Supervising Social Worker
# 1                                Assistant Care Manager
# 2                       Care Assistant / Support Worker
# 3                       Care Assistant / Support Worker
# 4                       Care Assistant / Support Worker
# 5                       Care Assistant / Support Worker
# 6     Children's Social Worker - Level 2 - Lincolnshire
# 7     Experienced Social Workers - Children's Social...
# 8                      Team Managers Adolescent Service
# 9     Experienced Children's Qualified Social Worker...
# 10           Mental Health Specialist/ Project Manager
# 11        Social Worker | MASH Team | South West Region
# 12    Head of Service | Child Protection Service | S...
# 13              Fostering Manager - Outstanding Service
# 14     Social Worker - Looked After Children - LAC Team
# 15    Qualified Social Worker - Multi - disciplinary...
# 16       Social Worker - Looked After Through Care Team
# 17    Senior Social Worker - Referral and Assessment...
# 18       LAC - Social Worker - Accommodation Allowance!
# 19                   Social Worker - CWD - Good Salary!
# 20    AMHP - Flexible Hours - Competitive Pay - Locu...
# 21            Team Manager - Children's Permanence Team
# 22    Forensic Mental Health Social Worker - Multi- ...
# 23    Child Protection & LAC - £34-£40 per hour - Go...
# 24    Social Worker - Transitions - CWD or Transitio...
# 25    Adoption Practitioner - Outside IR35 - 1 Year ...
# 26               Social Worker - Child Protection/Court
# 27    Are you a Children's Social Worker looking for...
# 28                      Team Manager - Adults MASH Team
# 29                               Housing Support Worker
# ...                                                 ...
# 1710  Experienced Children's Qualified Social Worker...
# 1711  Experienced Children's Qualified Social Worker...
# 1712  Experienced Children's Qualified Social Worker...
# 1713  Experienced Children's Qualified Social Worker...
# 1714  Experienced Children's Qualified Social Worker...
# 1715            Qualified Social Worker - Adoption Team
# 1716                Strategic Manager - Adults Services
# 1717            Independent Assessor - flexible working
# 1718  Therapeutic Care Worker - Child Psychotherapy ...
# 1719  Experienced Children's Qualified Social Worker...
# 1720                                      Social Worker
# 1721             Supervising Social Worker - home based
# 1722  Adoption and Family Finding Team Social Worker...
# 1723    Qualified Social Worker - Looked after Children
# 1724  Qualified Social Worker - Children Disabilitie...
# 1725  Fostering and Adoption Social Workers – Presto...
# 1726  Qualified Social Worker - Surrey - Children's ...
# 1727              £35ph, South London, Managed Caseload
# 1728  Disabilities Team Social Worker - No CWD Exp N...
# 1729  EDT Social Workers Needed - Phone IV & Quick S...
# 1730       QSW - South East - LAC - Training for locums
# 1731  Qualified Social Worker- Low Caseloads - South...
# 1732                     Social Worker -CP-£40 per hour
# 1733            Condensed Week, £30ph, Capped Caseloads
# 1734               Operations Manager-EBD-Cover 4 Homes
# 1735  Qualified Social Worker - Safeguarding and Fam...
# 1736     C&F SOCIAL WORK TEAM MANAGERS - VARIOUS TEAMS
# 1737                                      OT-Adults-£33
# 1738  Qualified Social Worker – Child Protection, Ho...
# 1739               SPECIALIST TEAM SENIOR MANAGER ROLE
#
#                                                    link  \
# 0      \r\n\t/job/1401610100/supervising-social-work...
